# %% [markdown]
# # Description
# ---
#
# This notebook shows how to get started with the MLB-provided datasets for the [Google Cloud x MLB(TM) Hackathon](https://next2025challenge.devpost.com/).

# %% [markdown]
# #Setup
# ---

# %%
#@title Import Python Libraries
# General data science libraries
import pandas as pd
import numpy as np

# Pulling data from APIs, parsing JSON
import requests
import json

# Interfacing w/ Cloud Storage from Python
from google.cloud import storage

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import HTML

# %%
#@title Modify Settings

# Expand max column width when displaying data frames to handle longer text
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# # Exploring MLB Stats API
# ---
# The MLB Stats API ([see documentation here](https://console.cloud.google.com/storage/browser/gcp-mlb-hackathon-2025/datasets/mlb-statsapi-docs)) provides access to various MLB historical and present day data feeds, without authentication. The various data feeds here should be very useful in making progress on this project. The cells below show how to access data from various MLB Stats API endpoints and do some initial processing.

# %%
#@title Function to Process Results from Various MLB Stats API Endpoints
def process_endpoint_url(endpoint_url, pop_key=None):
  """
  Fetches data from a URL, parses JSON, and optionally pops a key.

  Args:
    endpoint_url: The URL to fetch data from.
    pop_key: The key to pop from the JSON data (optional, defaults to None).

  Returns:
    A pandas DataFrame containing the processed data
  """
  json_result = requests.get(endpoint_url).content

  data = json.loads(json_result)

   # if pop_key is provided, pop key and normalize nested fields
  if pop_key:
    df_result = pd.json_normalize(data.pop(pop_key), sep = '_')
  # if pop_key is not provided, normalize entire json
  else:
    df_result = pd.json_normalize(data)

  return df_result

# %%
#@title Sports (Different Baseball Leagues/Levels/Competitions)
sports_endpoint_url = 'https://statsapi.mlb.com/api/v1/sports'

sports = process_endpoint_url(sports_endpoint_url, 'sports')

display(sports)
# Out:
#       id code                 link                                   name  \
# 0      1  mlb     /api/v1/sports/1                  Major League Baseball
# 1     11  aaa    /api/v1/sports/11                               Triple-A
# 2     12  aax    /api/v1/sports/12                               Double-A
# 3     13  afa    /api/v1/sports/13                                 High-A
# 4     14  afx    /api/v1/sports/14                               Single-A
# 5     16  rok    /api/v1/sports/16                                 Rookie
# 6     17  win    /api/v1/sports/17                         Winter Leagues
# 7     21  min    /api/v1/sports/21                  Minor League Baseball
# 8     23  ind    /api/v1/sports/23                    Independent Leagues
# 9     61  nlb    /api/v1/sports/61                  Negro League Baseball
# 10    32  kor    /api/v1/sports/32           Korean Baseball Organization
# 11    31  jml    /api/v1/sports/31           Nippon Professional Baseball
# 12    51  int    /api/v1/sports/51                 International Baseball
# 13   509  nae   /api/v1/sports/509           International Baseball (18U)
# 14   510  nas   /api/v1/sports/510  International Baseball (16 and under)
# 15  6005  ame  /api/v1/sports/6005       International Baseball (amateur)
# 16    22  bbc    /api/v1/sports/22                       College Baseball
# 17   586  hsb   /api/v1/sports/586                   High School Baseball
#
#    abbreviation  sortOrder  activeStatus
# 0           MLB         11          True
# 1           AAA        101          True
# 2            AA        201          True
# 3            A+        301          True
# 4             A        401          True
# 5           ROK        701          True
# 6           WIN       1301          True
# 7        Minors       1402          True
# 8           IND       2101          True
# 9           NLB       2401          True
# 10          KOR       2601          True
# 11          NPB       2701          True
# 12          INT       3501          True
# 13          18U       3503          True
# 14          16U       3505          True
# 15          AME       3509          True
# 16      College       5101          True
# 17         H.S.       6201          True

# %%
#@title Leagues

# Can add "?sportId=1" to following URL for MLB only
leagues_endpoint_url = 'https://statsapi.mlb.com/api/v1/league'

leagues = process_endpoint_url(leagues_endpoint_url, 'leagues')

display(leagues)
# Out:
#       id                    name                link abbreviation  \
# 0    103         American League  /api/v1/league/103           AL
# 1    104         National League  /api/v1/league/104           NL
# 2    114           Cactus League  /api/v1/league/114           CL
# 3    115       Grapefruit League  /api/v1/league/115           GL
# 4    117    International League  /api/v1/league/117          INT
# ..   ...                     ...                 ...          ...
# 111  107        College Baseball  /api/v1/league/107          CBB
# 112  108        College Baseball  /api/v1/league/108          CBB
# 113  587          Showcase Games  /api/v1/league/587           SG
# 114  625           Tournament 12  /api/v1/league/625          T12
# 115  577  National Pro Fastpitch  /api/v1/league/577          NPF
#
#             nameShort seasonState  hasWildCard hasSplitSeason  numGames  \
# 0            American   offseason         True          False     162.0
# 1            National   offseason         True          False     162.0
# 2              Cactus   offseason        False          False       NaN
# 3          Grapefruit   offseason        False          False       NaN
# 4       International   offseason         True           True     150.0
# ..                ...         ...          ...            ...       ...
# 111  College Baseball   offseason        False          False       NaN
# 112  College Baseball   offseason        False          False       NaN
# 113    Showcase Games    inseason        False          False       NaN
# 114     Tournament 12   offseason        False          False       4.0
# 115               NPF   offseason        False          False       NaN
#
#     hasPlayoffPoints  ...  seasonDateInfo_postSeasonEndDate  \
# 0              False  ...                        2024-10-30
# 1              False  ...                        2024-10-30
# 2              False  ...                               NaN
# 3              False  ...                               NaN
# 4              False  ...                        2024-09-28
# ..               ...  ...                               ...
# 111            False  ...                               NaN
# 112            False  ...                               NaN
# 113            False  ...                               NaN
# 114            False  ...                               NaN
# 115            False  ...                               NaN
#
#      seasonDateInfo_seasonEndDate seasonDateInfo_offseasonStartDate  \
# 0                      2024-10-30                        2024-10-31
# 1                      2024-10-30                        2024-10-31
# 2                             NaN                        2024-03-27
# 3                             NaN                        2024-03-27
# 4                      2024-09-28                        2024-09-29
# ..                            ...                               ...
# 111                    2024-09-04                        2024-09-06
# 112                    2020-12-31                               NaN
# 113                    2024-12-31                               NaN
# 114                    2022-09-24                        2022-09-25
# 115                    2012-07-31                               NaN
#
#     seasonDateInfo_offSeasonEndDate  seasonDateInfo_seasonLevelGamedayType  \
# 0                        2024-12-31                                      P
# 1                        2024-12-31                                      P
# 2                        2024-12-31                                      F
# 3                        2024-12-31                                      F
# 4                        2024-12-31                                      Y
# ..                              ...                                    ...
# 111                      2024-12-31                                      Y
# 112                      2020-12-21                                      N
# 113                      2024-12-21                                    NaN
# 114                      2022-12-31                                      Y
# 115                      2012-12-21                                      N
#
#      seasonDateInfo_gameLevelGamedayType  \
# 0                                      P
# 1                                      P
# 2                                      F
# 3                                      F
# 4                                      Y
# ..                                   ...
# 111                                    Y
# 112                                    N
# 113                                  NaN
# 114                                    Y
# 115                                    N
#
#      seasonDateInfo_qualifierPlateAppearances  \
# 0                                         3.1
# 1                                         3.1
# 2                                         NaN
# 3                                         NaN
# 4                                         2.7
# ..                                        ...
# 111                                       NaN
# 112                                       NaN
# 113                                       NaN
# 114                                       NaN
# 115                                       NaN
#
#      seasonDateInfo_qualifierOutsPitched sport_id          sport_link
# 0                                    3.0      1.0    /api/v1/sports/1
# 1                                    3.0      1.0    /api/v1/sports/1
# 2                                    NaN      NaN                 NaN
# 3                                    NaN      NaN                 NaN
# 4                                    2.4     11.0   /api/v1/sports/11
# ..                                   ...      ...                 ...
# 111                                  NaN     22.0   /api/v1/sports/22
# 112                                  NaN     22.0   /api/v1/sports/22
# 113                                  NaN    586.0  /api/v1/sports/586
# 114                                  NaN      NaN                 NaN
# 115                                  NaN    576.0  /api/v1/sports/576
#
# [116 rows x 40 columns]

# %%
#@title Seasons

# Use "?sportId=1" in following URL for MLB only
# Can also add "&withGameTypeDates=true" at end to get much more info on games
seasons_endpoint_url = 'https://statsapi.mlb.com/api/v1/seasons/all?sportId=1'

seasons = process_endpoint_url(seasons_endpoint_url, 'seasons')

display(seasons)
# Out:
#     seasonId  hasWildcard preSeasonStartDate seasonStartDate  \
# 0       1876        False         1876-01-01      1876-04-22
# 1       1877        False         1877-01-01      1877-04-30
# 2       1878        False         1878-01-01      1878-05-01
# 3       1879        False         1879-01-01      1879-05-01
# 4       1880        False         1880-01-01      1880-05-01
# ..       ...          ...                ...             ...
# 146     2022         True         2022-01-01      2022-02-27
# 147     2023         True         2023-01-01      2023-02-24
# 148     2024         True         2024-01-01      2024-02-22
# 149     2025         True         2025-01-01      2025-02-20
# 150     2026         True         2026-01-01      2026-02-20
#
#     regularSeasonStartDate regularSeasonEndDate seasonEndDate  \
# 0               1876-04-22           1876-10-09    1876-10-09
# 1               1877-04-30           1877-10-06    1877-10-06
# 2               1878-05-01           1878-09-30    1878-09-30
# 3               1879-05-01           1879-09-30    1879-09-30
# 4               1880-05-01           1880-10-01    1880-10-01
# ..                     ...                  ...           ...
# 146             2022-04-07           2022-10-05    2022-11-05
# 147             2023-03-30           2023-10-02    2023-11-01
# 148             2024-03-20           2024-09-30    2024-10-30
# 149             2025-03-26           2025-09-28    2025-10-31
# 150             2026-03-26           2026-09-28    2026-10-31
#
#     offseasonStartDate offSeasonEndDate seasonLevelGamedayType  ...  \
# 0           1876-10-10       1877-04-29                      S  ...
# 1           1877-10-07       1878-04-30                      S  ...
# 2           1878-10-01       1879-04-30                      S  ...
# 3           1879-10-01       1880-04-30                      S  ...
# 4           1880-10-02       1881-04-29                      S  ...
# ..                 ...              ...                    ...  ...
# 146         2022-11-06       2022-12-31                      P  ...
# 147         2023-11-02       2023-12-31                      P  ...
# 148         2024-10-31       2024-12-31                      P  ...
# 149         2025-11-01       2025-12-31                      P  ...
# 150         2026-11-01       2026-12-31                      P  ...
#
#     qualifierPlateAppearances  qualifierOutsPitched  postSeasonStartDate  \
# 0                         3.1                   3.0                  NaN
# 1                         3.1                   3.0                  NaN
# 2                         3.1                   3.0                  NaN
# 3                         3.1                   3.0                  NaN
# 4                         3.1                   3.0                  NaN
# ..                        ...                   ...                  ...
# 146                       3.1                   3.0           2022-10-07
# 147                       3.1                   3.0           2023-10-03
# 148                       3.1                   3.0           2024-10-01
# 149                       3.1                   3.0           2025-09-30
# 150                       3.1                   3.0           2026-09-30
#
#     postSeasonEndDate lastDate1stHalf allStarDate firstDate2ndHalf  \
# 0                 NaN             NaN         NaN              NaN
# 1                 NaN             NaN         NaN              NaN
# 2                 NaN             NaN         NaN              NaN
# 3                 NaN             NaN         NaN              NaN
# 4                 NaN             NaN         NaN              NaN
# ..                ...             ...         ...              ...
# 146        2022-11-05      2022-07-17  2022-07-19       2022-07-21
# 147        2023-11-01      2023-07-09  2023-07-11       2023-07-14
# 148        2024-10-30      2024-07-14  2024-07-16       2024-07-19
# 149        2025-10-31      2025-07-14  2025-07-15       2025-07-19
# 150        2026-10-31      2026-07-14  2026-07-15       2026-07-19
#
#     preSeasonEndDate springStartDate springEndDate
# 0                NaN             NaN           NaN
# 1                NaN             NaN           NaN
# 2                NaN             NaN           NaN
# 3                NaN             NaN           NaN
# 4                NaN             NaN           NaN
# ..               ...             ...           ...
# 146       2022-02-26      2022-02-27    2022-04-06
# 147       2023-02-23      2023-02-24    2023-03-28
# 148       2024-02-21      2024-02-22    2024-03-26
# 149       2025-02-19      2025-02-20    2025-03-25
# 150       2026-02-19      2026-02-20    2026-03-25
#
# [151 rows x 21 columns]

# %%
#@title Teams
# Use "?sportId=1" in following URL for MLB only
teams_endpoint_url = 'https://statsapi.mlb.com/api/v1/teams?sportId=1'

teams = process_endpoint_url(teams_endpoint_url, 'teams')

display(teams)
# Out:
#    allStarStatus   id                   name               link  season  \
# 0              N  133              Athletics  /api/v1/teams/133    2024
# 1              N  134     Pittsburgh Pirates  /api/v1/teams/134    2024
# 2              N  135       San Diego Padres  /api/v1/teams/135    2024
# 3              N  136       Seattle Mariners  /api/v1/teams/136    2024
# 4              N  137   San Francisco Giants  /api/v1/teams/137    2024
# 5              N  138    St. Louis Cardinals  /api/v1/teams/138    2024
# 6              N  139         Tampa Bay Rays  /api/v1/teams/139    2024
# 7              N  140          Texas Rangers  /api/v1/teams/140    2024
# 8              N  141      Toronto Blue Jays  /api/v1/teams/141    2024
# 9              N  142        Minnesota Twins  /api/v1/teams/142    2024
# 10             N  143  Philadelphia Phillies  /api/v1/teams/143    2024
# 11             N  144         Atlanta Braves  /api/v1/teams/144    2024
# 12             N  145      Chicago White Sox  /api/v1/teams/145    2024
# 13             N  146          Miami Marlins  /api/v1/teams/146    2024
# 14             N  147       New York Yankees  /api/v1/teams/147    2024
# 15             N  158      Milwaukee Brewers  /api/v1/teams/158    2024
# 16             N  108     Los Angeles Angels  /api/v1/teams/108    2024
# 17             N  109   Arizona Diamondbacks  /api/v1/teams/109    2024
# 18             N  110      Baltimore Orioles  /api/v1/teams/110    2024
# 19             N  111         Boston Red Sox  /api/v1/teams/111    2024
# 20             N  112           Chicago Cubs  /api/v1/teams/112    2024
# 21             N  113        Cincinnati Reds  /api/v1/teams/113    2024
# 22             N  114    Cleveland Guardians  /api/v1/teams/114    2024
# 23             N  115       Colorado Rockies  /api/v1/teams/115    2024
# 24             N  116         Detroit Tigers  /api/v1/teams/116    2024
# 25             N  117         Houston Astros  /api/v1/teams/117    2024
# 26             N  118     Kansas City Royals  /api/v1/teams/118    2024
# 27             N  119    Los Angeles Dodgers  /api/v1/teams/119    2024
# 28             N  120   Washington Nationals  /api/v1/teams/120    2024
# 29             N  121          New York Mets  /api/v1/teams/121    2024
#
#    teamCode fileCode abbreviation   teamName    locationName  ...  \
# 0       ath      ath          ATH  Athletics      Sacramento  ...
# 1       pit      pit          PIT    Pirates      Pittsburgh  ...
# 2       sdn       sd           SD     Padres       San Diego  ...
# 3       sea      sea          SEA   Mariners         Seattle  ...
# 4       sfn       sf           SF     Giants   San Francisco  ...
# 5       sln      stl          STL  Cardinals       St. Louis  ...
# 6       tba       tb           TB       Rays  St. Petersburg  ...
# 7       tex      tex          TEX    Rangers       Arlington  ...
# 8       tor      tor          TOR  Blue Jays         Toronto  ...
# 9       min      min          MIN      Twins     Minneapolis  ...
# 10      phi      phi          PHI   Phillies    Philadelphia  ...
# 11      atl      atl          ATL     Braves         Atlanta  ...
# 12      cha      cws          CWS  White Sox         Chicago  ...
# 13      mia      mia          MIA    Marlins           Miami  ...
# 14      nya      nyy          NYY    Yankees           Bronx  ...
# 15      mil      mil          MIL    Brewers       Milwaukee  ...
# 16      ana      ana          LAA     Angels         Anaheim  ...
# 17      ari      ari           AZ    D-backs         Phoenix  ...
# 18      bal      bal          BAL    Orioles       Baltimore  ...
# 19      bos      bos          BOS    Red Sox          Boston  ...
# 20      chn      chc          CHC       Cubs         Chicago  ...
# 21      cin      cin          CIN       Reds      Cincinnati  ...
# 22      cle      cle          CLE  Guardians       Cleveland  ...
# 23      col      col          COL    Rockies          Denver  ...
# 24      det      det          DET     Tigers         Detroit  ...
# 25      hou      hou          HOU     Astros         Houston  ...
# 26      kca       kc           KC     Royals     Kansas City  ...
# 27      lan       la          LAD    Dodgers     Los Angeles  ...
# 28      was      was          WSH  Nationals      Washington  ...
# 29      nyn      nym          NYM       Mets        Flushing  ...
#
#        springVenue_link league_id      league_name         league_link  \
# 0   /api/v1/venues/2507       103  American League  /api/v1/league/103
# 1   /api/v1/venues/2526       104  National League  /api/v1/league/104
# 2   /api/v1/venues/2530       104  National League  /api/v1/league/104
# 3   /api/v1/venues/2530       103  American League  /api/v1/league/103
# 4   /api/v1/venues/2532       104  National League  /api/v1/league/104
# 5   /api/v1/venues/2520       104  National League  /api/v1/league/104
# 6   /api/v1/venues/2534       103  American League  /api/v1/league/103
# 7   /api/v1/venues/2603       103  American League  /api/v1/league/103
# 8   /api/v1/venues/2536       103  American League  /api/v1/league/103
# 9   /api/v1/venues/2862       103  American League  /api/v1/league/103
# 10  /api/v1/venues/2700       104  National League  /api/v1/league/104
# 11  /api/v1/venues/5380       104  National League  /api/v1/league/104
# 12  /api/v1/venues/3809       103  American League  /api/v1/league/103
# 13  /api/v1/venues/2520       104  National League  /api/v1/league/104
# 14  /api/v1/venues/2523       103  American League  /api/v1/league/103
# 15  /api/v1/venues/2518       104  National League  /api/v1/league/104
# 16  /api/v1/venues/2500       103  American League  /api/v1/league/103
# 17  /api/v1/venues/4249       104  National League  /api/v1/league/104
# 18  /api/v1/venues/2508       103  American League  /api/v1/league/103
# 19  /api/v1/venues/4309       103  American League  /api/v1/league/103
# 20  /api/v1/venues/4629       104  National League  /api/v1/league/104
# 21  /api/v1/venues/3834       104  National League  /api/v1/league/104
# 22  /api/v1/venues/3834       103  American League  /api/v1/league/103
# 23  /api/v1/venues/4249       104  National League  /api/v1/league/104
# 24  /api/v1/venues/2511       103  American League  /api/v1/league/103
# 25  /api/v1/venues/5000       103  American League  /api/v1/league/103
# 26  /api/v1/venues/2603       103  American League  /api/v1/league/103
# 27  /api/v1/venues/3809       104  National League  /api/v1/league/104
# 28  /api/v1/venues/5000       104  National League  /api/v1/league/104
# 29  /api/v1/venues/2856       104  National League  /api/v1/league/104
#
#     division_id            division_name          division_link sport_id  \
# 0           200     American League West  /api/v1/divisions/200        1
# 1           205  National League Central  /api/v1/divisions/205        1
# 2           203     National League West  /api/v1/divisions/203        1
# 3           200     American League West  /api/v1/divisions/200        1
# 4           203     National League West  /api/v1/divisions/203        1
# 5           205  National League Central  /api/v1/divisions/205        1
# 6           201     American League East  /api/v1/divisions/201        1
# 7           200     American League West  /api/v1/divisions/200        1
# 8           201     American League East  /api/v1/divisions/201        1
# 9           202  American League Central  /api/v1/divisions/202        1
# 10          204     National League East  /api/v1/divisions/204        1
# 11          204     National League East  /api/v1/divisions/204        1
# 12          202  American League Central  /api/v1/divisions/202        1
# 13          204     National League East  /api/v1/divisions/204        1
# 14          201     American League East  /api/v1/divisions/201        1
# 15          205  National League Central  /api/v1/divisions/205        1
# 16          200     American League West  /api/v1/divisions/200        1
# 17          203     National League West  /api/v1/divisions/203        1
# 18          201     American League East  /api/v1/divisions/201        1
# 19          201     American League East  /api/v1/divisions/201        1
# 20          205  National League Central  /api/v1/divisions/205        1
# 21          205  National League Central  /api/v1/divisions/205        1
# 22          202  American League Central  /api/v1/divisions/202        1
# 23          203     National League West  /api/v1/divisions/203        1
# 24          202  American League Central  /api/v1/divisions/202        1
# 25          200     American League West  /api/v1/divisions/200        1
# 26          202  American League Central  /api/v1/divisions/202        1
# 27          203     National League West  /api/v1/divisions/203        1
# 28          204     National League East  /api/v1/divisions/204        1
# 29          204     National League East  /api/v1/divisions/204        1
#
#           sport_link             sport_name
# 0   /api/v1/sports/1  Major League Baseball
# 1   /api/v1/sports/1  Major League Baseball
# 2   /api/v1/sports/1  Major League Baseball
# 3   /api/v1/sports/1  Major League Baseball
# 4   /api/v1/sports/1  Major League Baseball
# 5   /api/v1/sports/1  Major League Baseball
# 6   /api/v1/sports/1  Major League Baseball
# 7   /api/v1/sports/1  Major League Baseball
# 8   /api/v1/sports/1  Major League Baseball
# 9   /api/v1/sports/1  Major League Baseball
# 10  /api/v1/sports/1  Major League Baseball
# 11  /api/v1/sports/1  Major League Baseball
# 12  /api/v1/sports/1  Major League Baseball
# 13  /api/v1/sports/1  Major League Baseball
# 14  /api/v1/sports/1  Major League Baseball
# 15  /api/v1/sports/1  Major League Baseball
# 16  /api/v1/sports/1  Major League Baseball
# 17  /api/v1/sports/1  Major League Baseball
# 18  /api/v1/sports/1  Major League Baseball
# 19  /api/v1/sports/1  Major League Baseball
# 20  /api/v1/sports/1  Major League Baseball
# 21  /api/v1/sports/1  Major League Baseball
# 22  /api/v1/sports/1  Major League Baseball
# 23  /api/v1/sports/1  Major League Baseball
# 24  /api/v1/sports/1  Major League Baseball
# 25  /api/v1/sports/1  Major League Baseball
# 26  /api/v1/sports/1  Major League Baseball
# 27  /api/v1/sports/1  Major League Baseball
# 28  /api/v1/sports/1  Major League Baseball
# 29  /api/v1/sports/1  Major League Baseball
#
# [30 rows x 33 columns]

# %%
#@title Single Team Roster

# Pick single team ID to get roster for (default is 119 for Dodgers)
team_id = 119 # @param {type:"integer"}

single_team_roster_url = f'https://statsapi.mlb.com/api/v1/teams/{team_id}/roster?season=2024'

single_team_roster = process_endpoint_url(single_team_roster_url, 'roster')

display(single_team_roster)
# Out:
#    jerseyNumber  parentTeamId  person_id     person_fullName  \
# 0            51           119     681911          Alex Vesia
# 1            44           119     681624          Andy Pages
# 2            43           119     607455       Anthony Banda
# 3            15           119     605131       Austin Barnes
# 4            78           119     676508       Ben Casparius
# 5             7           119     605483         Blake Snell
# 6            49           119     595014       Blake Treinen
# 7            28           119     676272        Bobby Miller
# 8            48           119     660813    Brusdar Graterol
# 9             3           119     621035        Chris Taylor
# 10           76           119     682616       Diego Cartaya
# 11           85           119     669160          Dustin May
# 12           60           119     683618   Edgardo Henriquez
# 13           80           119     686218       Emmet Sheehan
# 14           59           119     623465       Evan Phillips
# 15            5           119     518692     Freddie Freeman
# 16            9           119     666158           Gavin Lux
# 17           35           119     694813         Gavin Stone
# 18           67           119     676439     Hunter Feduccia
# 19                        119     676263         Jack Dreyer
# 20           33           119     681546        James Outman
# 21           70           119     680736    Justin Wrobleski
# 22           63           119     669165           Kyle Hurt
# 23           96           119     689017        Landon Knack
# 24           13           119     571970           Max Muncy
# 25                        119     624424    Michael Conforto
# 26           29           119     675627       Michael Grove
# 27           45           119     656629      Michael Kopech
# 28           11           119     500743        Miguel Rojas
# 29           50           119     605141        Mookie Betts
# 30           79           119     693308         Nick Frasso
# 31           77           119     689981          River Ryan
# 32           57           119     518489        Ryan Brasier
# 33           17           119     660271       Shohei Ohtani
# 34           25           119     669242         Tommy Edman
# 35           26           119     664062       Tony Gonsolin
# 36           31           119     607192       Tyler Glasnow
# 37           16           119     669257          Will Smith
# 38           18           119     808967  Yoshinobu Yamamoto
#
#               person_link position_code   position_name   position_type  \
# 0   /api/v1/people/681911             1         Pitcher         Pitcher
# 1   /api/v1/people/681624             8      Outfielder      Outfielder
# 2   /api/v1/people/607455             1         Pitcher         Pitcher
# 3   /api/v1/people/605131             2         Catcher         Catcher
# 4   /api/v1/people/676508             1         Pitcher         Pitcher
# 5   /api/v1/people/605483             1         Pitcher         Pitcher
# 6   /api/v1/people/595014             1         Pitcher         Pitcher
# 7   /api/v1/people/676272             1         Pitcher         Pitcher
# 8   /api/v1/people/660813             1         Pitcher         Pitcher
# 9   /api/v1/people/621035             7      Outfielder      Outfielder
# 10  /api/v1/people/682616             2         Catcher         Catcher
# 11  /api/v1/people/669160             1         Pitcher         Pitcher
# 12  /api/v1/people/683618             1         Pitcher         Pitcher
# 13  /api/v1/people/686218             1         Pitcher         Pitcher
# 14  /api/v1/people/623465             1         Pitcher         Pitcher
# 15  /api/v1/people/518692             3      First Base       Infielder
# 16  /api/v1/people/666158             4     Second Base       Infielder
# 17  /api/v1/people/694813             1         Pitcher         Pitcher
# 18  /api/v1/people/676439             2         Catcher         Catcher
# 19  /api/v1/people/676263             1         Pitcher         Pitcher
# 20  /api/v1/people/681546             8      Outfielder      Outfielder
# 21  /api/v1/people/680736             1         Pitcher         Pitcher
# 22  /api/v1/people/669165             1         Pitcher         Pitcher
# 23  /api/v1/people/689017             1         Pitcher         Pitcher
# 24  /api/v1/people/571970             5      Third Base       Infielder
# 25  /api/v1/people/624424             7      Outfielder      Outfielder
# 26  /api/v1/people/675627             1         Pitcher         Pitcher
# 27  /api/v1/people/656629             1         Pitcher         Pitcher
# 28  /api/v1/people/500743             6       Shortstop       Infielder
# 29  /api/v1/people/605141             6       Shortstop       Infielder
# 30  /api/v1/people/693308             1         Pitcher         Pitcher
# 31  /api/v1/people/689981             1         Pitcher         Pitcher
# 32  /api/v1/people/518489             1         Pitcher         Pitcher
# 33  /api/v1/people/660271             Y  Two-Way Player  Two-Way Player
# 34  /api/v1/people/669242             8      Outfielder      Outfielder
# 35  /api/v1/people/664062             1         Pitcher         Pitcher
# 36  /api/v1/people/607192             1         Pitcher         Pitcher
# 37  /api/v1/people/669257             2         Catcher         Catcher
# 38  /api/v1/people/808967             1         Pitcher         Pitcher
#
#    position_abbreviation status_code status_description
# 0                      P           A             Active
# 1                     CF           A             Active
# 2                      P           A             Active
# 3                      C           A             Active
# 4                      P           A             Active
# 5                      P           A             Active
# 6                      P           A             Active
# 7                      P           A             Active
# 8                      P           A             Active
# 9                     LF           A             Active
# 10                     C           A             Active
# 11                     P           A             Active
# 12                     P           A             Active
# 13                     P           A             Active
# 14                     P           A             Active
# 15                    1B           A             Active
# 16                    2B           A             Active
# 17                     P           A             Active
# 18                     C           A             Active
# 19                     P           A             Active
# 20                    CF           A             Active
# 21                     P           A             Active
# 22                     P           A             Active
# 23                     P           A             Active
# 24                    3B           A             Active
# 25                    LF           A             Active
# 26                     P           A             Active
# 27                     P           A             Active
# 28                    SS           A             Active
# 29                    SS           A             Active
# 30                     P           A             Active
# 31                     P           A             Active
# 32                     P           A             Active
# 33                   TWP           A             Active
# 34                    CF           A             Active
# 35                     P           A             Active
# 36                     P           A             Active
# 37                     C           A             Active
# 38                     P           A             Active

# %%
#@title Single Player Information
# Pick single player ID to get info for (default is 660271 for Shohei Ohtani)
player_id = 660271 # @param {type:"integer"}

single_player_url = f'https://statsapi.mlb.com/api/v1/people/{player_id}/'

single_player_info_json = json.loads(requests.get(single_player_url).content)

display(single_player_info_json)
# Out:
# {'copyright': 'Copyright 2024 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'people': [{'id': 660271,
#    'fullName': 'Shohei Ohtani',
#    'link': '/api/v1/people/660271',
#    'firstName': 'Shohei',
#    'lastName': 'Ohtani',
#    'primaryNumber': '17',
#    'birthDate': '1994-07-05',
#    'currentAge': 30,
#    'birthCity': 'Oshu',
#    'birthCountry': 'Japan',
#    'height': '6\' 4"',
#    'weight': 210,
#    'active': True,
#    'primaryPosition': {'code': 'Y',
#     'name': 'Two-Way Player',
#     'type': 'Two-Way Player',
#     'abbreviation': 'TWP'},
#    'useName': 'Shohei',
#    'useLastName': 'Ohtani',
#    'boxscoreName': 'Ohtani',
#    'nickName': 'Showtime',
#    'gender': 'M',
#    'isPlayer': True,
#    'isVerified': False,
#    'pronunciation': 'show-HEY oh-TAWN-ee',
#    'mlbDebutDate': '2018-03-29',
#    'batSide': {'code': 'L', 'description': 'Left'},
#    'pitchHand': {'code': 'R', 'description': 'Right'},
#    'nameFirstLast': 'Shohei Ohtani',
#    'nameSlug': 'shohei-ohtani-660271',
#    'firstLastName': 'Shohei Ohtani',
#    'lastFirstName': 'Ohtani, Shohei',
#    'lastInitName': 'Ohtani, S',
#    'initLastName': 'S Ohtani',
#    'fullFMLName': 'Shohei Ohtani',
#    'fullLFMName': 'Ohtani, Shohei',
#    'strikeZoneTop': 3.4,
#    'strikeZoneBottom': 1.62}]}

# %%
#@title Schedule / Games
# Use "?sportId=1" in following URL for MLB only
# Can change season to get other seasons' games info
schedule_endpoint_url = 'https://statsapi.mlb.com/api/v1/schedule?sportId=1&season=2024'

schedule_dates = process_endpoint_url(schedule_endpoint_url, "dates")

games = pd.json_normalize(
    schedule_dates.explode('games').reset_index(drop = True)['games'])

display(games)
# Out:
#       gamePk                              gameGuid  \
# 0     748266  d5cb4300-04fc-4cd0-9a62-88099e61bd81
# 1     748344  1ae43208-ddd5-4d32-af13-334857bddb80
# 2     748263  33b22841-8ae2-4589-9e93-64bfe9efdf8a
# 3     748341  1e162b85-6a35-4a0b-a0f1-da6ee9b74b4d
# 4     748260  a4192578-af76-46e9-be87-98dfe2ade3a6
# ...      ...                                   ...
# 2993  775300  fb97fd78-be7e-4439-b30c-733a91400fbf
# 2994  775294  e8d50a03-7c3f-44f5-87bb-43476e34fe94
# 2995  775298  e6fed413-e8ca-4217-bdf0-d13912b4411a
# 2996  775297  79cb2c8c-d698-49f7-9c33-0bb7a6895efb
# 2997  775296  920f8c2c-a626-4716-9ffb-89b3059e2dfe
#
#                                  link gameType season              gameDate  \
# 0     /api/v1.1/game/748266/feed/live        S   2024  2024-02-22T20:10:00Z
# 1     /api/v1.1/game/748344/feed/live        E   2024  2024-02-23T18:05:00Z
# 2     /api/v1.1/game/748263/feed/live        S   2024  2024-02-23T20:05:00Z
# 3     /api/v1.1/game/748341/feed/live        S   2024  2024-02-23T20:05:00Z
# 4     /api/v1.1/game/748260/feed/live        S   2024  2024-02-23T20:08:00Z
# ...                               ...      ...    ...                   ...
# 2993  /api/v1.1/game/775300/feed/live        W   2024  2024-10-26T00:08:00Z
# 2994  /api/v1.1/game/775294/feed/live        W   2024  2024-10-27T00:08:00Z
# 2995  /api/v1.1/game/775298/feed/live        W   2024  2024-10-29T00:08:00Z
# 2996  /api/v1.1/game/775297/feed/live        W   2024  2024-10-30T00:08:00Z
# 2997  /api/v1.1/game/775296/feed/live        W   2024  2024-10-31T00:08:00Z
#
#      officialDate  isTie  gameNumber  publicFacing  ... status.reason  \
# 0      2024-02-22  False           1          True  ...           NaN
# 1      2024-02-23  False           1          True  ...           NaN
# 2      2024-02-23  False           1          True  ...           NaN
# 3      2024-02-23  False           1          True  ...           NaN
# 4      2024-02-23  False           1          True  ...           NaN
# ...           ...    ...         ...           ...  ...           ...
# 2993   2024-10-25  False           1          True  ...           NaN
# 2994   2024-10-26  False           1          True  ...           NaN
# 2995   2024-10-28  False           1          True  ...           NaN
# 2996   2024-10-29  False           1          True  ...           NaN
# 2997   2024-10-30  False           1          True  ...           NaN
#
#               description rescheduleDate rescheduleGameDate rescheduledFrom  \
# 0                     NaN            NaN                NaN             NaN
# 1                     NaN            NaN                NaN             NaN
# 2                     NaN            NaN                NaN             NaN
# 3                     NaN            NaN                NaN             NaN
# 4                     NaN            NaN                NaN             NaN
# ...                   ...            ...                ...             ...
# 2993  World Series Game 1            NaN                NaN             NaN
# 2994  World Series Game 2            NaN                NaN             NaN
# 2995  World Series Game 3            NaN                NaN             NaN
# 2996  World Series Game 4            NaN                NaN             NaN
# 2997  World Series Game 5            NaN                NaN             NaN
#
#      rescheduledFromDate  resumeDate  resumeGameDate  resumedFrom  \
# 0                    NaN         NaN             NaN          NaN
# 1                    NaN         NaN             NaN          NaN
# 2                    NaN         NaN             NaN          NaN
# 3                    NaN         NaN             NaN          NaN
# 4                    NaN         NaN             NaN          NaN
# ...                  ...         ...             ...          ...
# 2993                 NaN         NaN             NaN          NaN
# 2994                 NaN         NaN             NaN          NaN
# 2995                 NaN         NaN             NaN          NaN
# 2996                 NaN         NaN             NaN          NaN
# 2997                 NaN         NaN             NaN          NaN
#
#       resumedFromDate
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 2993              NaN
# 2994              NaN
# 2995              NaN
# 2996              NaN
# 2997              NaN
#
# [2998 rows x 65 columns]

# %% [markdown]
# After getting the full season schedule, we can pick 1 game (via "gamePk") to pull detailed data for, as is done below (we default to the last game in the result above).

# %%
#@title Single Game Full Data

# Pick gamePK of last game from games data as default
game_pk = games['gamePk'].iloc[-1]

single_game_feed_url = f'https://statsapi.mlb.com/api/v1.1/game/{game_pk}/feed/live'

single_game_info_json = json.loads(requests.get(single_game_feed_url).content)

# Print the initial part of the JSON result (very large object with many fields)
display(json.dumps(single_game_info_json)[:1000])
# Out:
# '{"copyright": "Copyright 2024 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt", "gamePk": 775296, "link": "/api/v1.1/game/775296/feed/live", "metaData": {"wait": 10, "timeStamp": "20241031_035122", "gameEvents": ["strikeout", "game_finished"], "logicalEvents": ["midInning", "countChange", "count13", "gameStateChangeToGameOver"]}, "gameData": {"game": {"pk": 775296, "type": "W", "doubleHeader": "N", "id": "2024/10/30/lanmlb-nyamlb-1", "gamedayType": "P", "tiebreaker": "N", "gameNumber": 1, "calendarEventID": "14-775296-2024-10-30", "season": "2024", "seasonDisplay": "2024"}, "datetime": {"dateTime": "2024-10-31T00:08:00Z", "originalDate": "2024-10-30", "officialDate": "2024-10-30", "dayNight": "night", "time": "8:08", "ampm": "PM"}, "status": {"abstractGameState": "Final", "codedGameState": "F", "detailedState": "Final", "statusCode": "F", "startTimeTBD": false, "abstractGameCode": "F"}'

# %% [markdown]
# That game data feed has a lot of detailed information about the game itself, the teams, the players, and what happened on every pitch. Below, we extract all the information on the last ("current") play from the game chosen above, to show all the information available for every pitch.

# %%
#@title Single Play Information (from Game Data)
# Default to getting info on "current" (last) play from single game info above
single_game_play = single_game_info_json['liveData']['plays']['currentPlay']

display(single_game_play)
# Out:
# {'result': {'type': 'atBat',
#   'event': 'Strikeout',
#   'eventType': 'strikeout',
#   'description': 'Alex Verdugo strikes out swinging.',
#   'rbi': 0,
#   'awayScore': 7,
#   'homeScore': 6,
#   'isOut': True},
#  'about': {'atBatIndex': 88,
#   'halfInning': 'bottom',
#   'isTopInning': False,
#   'inning': 9,
#   'startTime': '2024-10-31T03:50:09.726Z',
#   'endTime': '2024-10-31T03:51:22.288Z',
#   'isComplete': True,
#   'isScoringPlay': False,
#   'hasReview': False,
#   'hasOut': True,
#   'captivatingIndex': 14},
#  'count': {'balls': 1, 'strikes': 3, 'outs': 3},
#  'matchup': {'batter': {'id': 657077,
#    'fullName': 'Alex Verdugo',
#    'link': '/api/v1/people/657077'},
#   'batSide': {'code': 'L', 'description': 'Left'},
#   'pitcher': {'id': 621111,
#    'fullName': 'Walker Buehler',
#    'link': '/api/v1/people/621111'},
#   'pitchHand': {'code': 'R', 'description': 'Right'},
#   'batterHotColdZones': [],
#   'pitcherHotColdZones': [],
#   'splits': {'batter': 'vs_RHP', 'pitcher': 'vs_LHB', 'menOnBase': 'Empty'}},
#  'pitchIndex': [0, 1, 2, 3],
#  'actionIndex': [],
#  'runnerIndex': [0],
#  'runners': [{'movement': {'originBase': None,
#     'start': None,
#     'end': None,
#     'outBase': '1B',
#     'isOut': True,
#     'outNumber': 3},
#    'details': {'event': 'Strikeout',
#     'eventType': 'strikeout',
#     'movementReason': None,
#     'runner': {'id': 657077,
#      'fullName': 'Alex Verdugo',
#      'link': '/api/v1/people/657077'},
#     'responsiblePitcher': None,
#     'isScoringEvent': False,
#     'rbi': False,
#     'earned': False,
#     'teamUnearned': False,
#     'playIndex': 3},
#    'credits': [{'player': {'id': 669257, 'link': '/api/v1/people/669257'},
#      'position': {'code': '2',
#       'name': 'Catcher',
#       'type': 'Catcher',
#       'abbreviation': 'C'},
#      'credit': 'f_putout'}]}],
#  'playEvents': [{'details': {'call': {'code': 'B', 'description': 'Ball'},
#     'description': 'Ball',
#     'code': 'B',
#     'ballColor': 'rgba(39, 161, 39, 1.0)',
#     'trailColor': 'rgba(153, 171, 0, 1.0)',
#     'isInPlay': False,
#     'isStrike': False,
#     'isBall': True,
#     'type': {'code': 'KC', 'description': 'Knuckle Curve'},
#     'isOut': False,
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 0, 'outs': 2},
#    'pitchData': {'startSpeed': 78.5,
#     'endSpeed': 71.5,
#     'strikeZoneTop': 3.34424680176383,
#     'strikeZoneBottom': 1.49649913462461,
#     'coordinates': {'aY': 25.35436038269367,
#      'aZ': -44.40859335204685,
#      'pfxX': 6.918497370104339,
#      'pfxZ': -9.480114985189488,
#      'pX': -0.08731244336026654,
#      'pZ': 1.1122271636053997,
#      'vX0': 0.43020717584758905,
#      'vY0': -114.1854313684875,
#      'vZ0': -0.3490221612532247,
#      'x': 120.33,
#      'y': 208.75,
#      'x0': -1.1752701285942835,
#      'y0': 50.00047134117033,
#      'z0': 5.719812290733207,
#      'aX': 8.932325350787155},
#     'breaks': {'breakAngle': 12.0,
#      'breakLength': 14.4,
#      'breakY': 24.0,
#      'breakVertical': -61.9,
#      'breakVerticalInduced': -16.8,
#      'breakHorizontal': -12.6,
#      'spinRate': 2515,
#      'spinDirection': 23},
#     'zone': 13,
#     'typeConfidence': 0.9,
#     'plateTime': 0.4837937599423663,
#     'extension': 6.19758299733275},
#    'index': 0,
#    'playId': 'f7ffcd29-30f9-4bf2-b9d8-a875ff1d3028',
#    'pitchNumber': 1,
#    'startTime': '2024-10-31T03:50:26.304Z',
#    'endTime': '2024-10-31T03:50:29.304Z',
#    'isPitch': True,
#    'type': 'pitch'},
#   {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#     'description': 'Swinging Strike',
#     'code': 'S',
#     'ballColor': 'rgba(170, 21, 11, 1.0)',
#     'trailColor': 'rgba(152, 0, 101, 1.0)',
#     'isInPlay': False,
#     'isStrike': True,
#     'isBall': False,
#     'type': {'code': 'FC', 'description': 'Cutter'},
#     'isOut': False,
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 1, 'outs': 2},
#    'pitchData': {'startSpeed': 93.1,
#     'endSpeed': 85.7,
#     'strikeZoneTop': 3.42,
#     'strikeZoneBottom': 1.55,
#     'coordinates': {'aY': 28.588943362646216,
#      'aZ': -22.336038777467845,
#      'pfxX': 2.9207517265072616,
#      'pfxZ': 5.264533691014945,
#      'pX': 1.2840491448778302,
#      'pZ': 2.104541022180739,
#      'vX0': 5.208109935353329,
#      'vY0': -135.54407474571795,
#      'vZ0': -4.664347129241177,
#      'x': 68.06,
#      'y': 181.96,
#      'x0': -1.038766771181746,
#      'y0': 50.00041269902904,
#      'z0': 5.399761188905378,
#      'aX': 5.452183734966475},
#     'breaks': {'breakAngle': 15.6,
#      'breakLength': 4.8,
#      'breakY': 24.0,
#      'breakVertical': -22.7,
#      'breakVerticalInduced': 8.8,
#      'breakHorizontal': -6.4,
#      'spinRate': 2527,
#      'spinDirection': 176},
#     'zone': 14,
#     'typeConfidence': 0.91,
#     'plateTime': 0.4035268508156147,
#     'extension': 6.5489954036139535},
#    'index': 1,
#    'playId': '6300ee32-925a-423c-996c-c1a6d1314001',
#    'pitchNumber': 2,
#    'startTime': '2024-10-31T03:50:41.713Z',
#    'endTime': '2024-10-31T03:50:44.713Z',
#    'isPitch': True,
#    'type': 'pitch'},
#   {'details': {'call': {'code': 'S', 'description': 'Swinging Strike'},
#     'description': 'Swinging Strike',
#     'code': 'S',
#     'ballColor': 'rgba(170, 21, 11, 1.0)',
#     'trailColor': 'rgba(153, 171, 0, 1.0)',
#     'isInPlay': False,
#     'isStrike': True,
#     'isBall': False,
#     'type': {'code': 'KC', 'description': 'Knuckle Curve'},
#     'isOut': False,
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 2, 'outs': 2},
#    'pitchData': {'startSpeed': 78.7,
#     'endSpeed': 71.5,
#     'strikeZoneTop': 3.42,
#     'strikeZoneBottom': 1.55,
#     'coordinates': {'aY': 26.430825629120854,
#      'aZ': -45.59230358681623,
#      'pfxX': 6.881775870183117,
#      'pfxZ': -10.37750437000836,
#      'pX': 0.2765315201880111,
#      'pZ': 1.1725103920471232,
#      'vX0': 0.8408010027800801,
#      'vY0': -114.505808879767,
#      'vZ0': -0.056576900730509916,
#      'x': 106.46,
#      'y': 207.12,
#      'x0': -0.9898122066635545,
#      'y0': 50.005378528469805,
#      'z0': 5.760693258502554,
#      'aX': 8.894269381684703},
#     'breaks': {'breakAngle': 10.8,
#      'breakLength': 14.4,
#      'breakY': 24.0,
#      'breakVertical': -63.4,
#      'breakVerticalInduced': -18.4,
#      'breakHorizontal': -12.6,
#      'spinRate': 2649,
#      'spinDirection': 26},
#     'zone': 14,
#     'typeConfidence': 0.91,
#     'plateTime': 0.48333894911848585,
#     'extension': 6.402741399688317},
#    'index': 2,
#    'playId': 'fdc815b1-acc9-41cc-8420-4d05db6b7867',
#    'pitchNumber': 3,
#    'startTime': '2024-10-31T03:50:58.264Z',
#    'endTime': '2024-10-31T03:51:01.264Z',
#    'isPitch': True,
#    'type': 'pitch'},
#   {'details': {'call': {'code': 'W',
#      'description': 'Swinging Strike (Blocked)'},
#     'description': 'Swinging Strike (Blocked)',
#     'code': 'W',
#     'ballColor': 'rgba(170, 21, 11, 1.0)',
#     'trailColor': 'rgba(153, 171, 0, 1.0)',
#     'isInPlay': False,
#     'isStrike': True,
#     'isBall': False,
#     'type': {'code': 'KC', 'description': 'Knuckle Curve'},
#     'isOut': True,
#     'hasReview': False},
#    'count': {'balls': 1, 'strikes': 3, 'outs': 2},
#    'pitchData': {'startSpeed': 77.5,
#     'endSpeed': 70.6,
#     'strikeZoneTop': 3.42,
#     'strikeZoneBottom': 1.55,
#     'coordinates': {'aY': 24.929254012748277,
#      'aZ': -43.90409554004765,
#      'pfxX': 7.248063527245467,
#      'pfxZ': -9.312384022087297,
#      'pX': -0.20633269715737754,
#      'pZ': 1.0721541314638297,
#      'vX0': -0.055693265460640184,
#      'vY0': -112.79518712734452,
#      'vZ0': -0.1773572157882224,
#      'x': 124.86,
#      'y': 209.83,
#      'x0': -1.1191997791298132,
#      'y0': 50.00529840193558,
#      'z0': 5.666222932261145,
#      'aX': 9.125114553442266},
#     'breaks': {'breakAngle': 12.0,
#      'breakLength': 14.4,
#      'breakY': 24.0,
#      'breakVertical': -62.8,
#      'breakVerticalInduced': -16.4,
#      'breakHorizontal': -13.0,
#      'spinRate': 2403,
#      'spinDirection': 25},
#     'zone': 13,
#     'typeConfidence': 0.91,
#     'plateTime': 0.48994328034581924,
#     'extension': 6.6373158583637535},
#    'index': 3,
#    'playId': 'ea570f90-4cef-455e-80c0-19d94d56b4d2',
#    'pitchNumber': 4,
#    'startTime': '2024-10-31T03:51:19.029Z',
#    'endTime': '2024-10-31T03:51:22.288Z',
#    'isPitch': True,
#    'type': 'pitch'}],
#  'playEndTime': '2024-10-31T03:51:22.288Z',
#  'atBatIndex': 88}

# %% [markdown]
#  [MLB Film Room](https://www.mlb.com/video) gives fans incredible access to watch, create and share baseball highlights and videos from the game. The cell below shows how to take a single MLB playId from MLB Stats API (like the ones available in some of the outputs above) and then build a URL to find the video for that play on Film Room.

# %%
#@title Get MLB Film Room Video Link for Specific Play ID
# Pick single play ID to get info for (default is Freddie Freeman 2024 WS Gm1 walk-off grand slam)
play_id = "560a2f9b-9589-4e4b-95f5-2ef796334a94" # @param {type:"string"}

single_play_video_url = f'https://www.mlb.com/video/search?q=playid=\"{play_id}\"'

display(single_play_video_url)
# Out:
# 'https://www.mlb.com/video/search?q=playid="560a2f9b-9589-4e4b-95f5-2ef796334a94"'

# %% [markdown]
# # Exploring 2024 MLB Home Runs Data and Video
# ---
# [One of the provided datasets](https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/2024-mlb-homeruns.csv) has a link to a public video file for each home run hit during the 2024 MLB regular season, along with some basic information about every HR. These links can be used to watch video to help corroborate what's in the data for a specific HR, and also the video can serve as a basis for AI-driven analysis or recommendations.

# %%
#@title Get 2024 MLB Home Runs Data from Cloud Storage

mlb_2024_hr_csv = 'https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/2024-mlb-homeruns.csv'

mlb_2024_hr_df = pd.read_csv(mlb_2024_hr_csv)

display(mlb_2024_hr_df.head())
# Out:
#                                 play_id  \
# 0  148e943b-10db-4d71-943d-ead3b36bebbc
# 1  d4116f91-e362-4261-a7d0-fc02f0eeb67b
# 2  2d6363ad-8ff2-49cc-bf21-d8cdfdc55999
# 3  e97b2fb3-a7b9-4a4b-812a-f1204437a06f
# 4  3423ed8c-5945-46e0-89f4-d6ed2baf5696
#
#                                                                                                               title  \
# 0                                 Freddie Freeman homers (1) on a fly ball to center field.   Shohei Ohtani scores.
# 1                                                              Mookie Betts homers (2) on a fly ball to left field.
# 2                                                    George Springer homers (1) on a fly ball to left center field.
# 3                                                          Paul Goldschmidt homers (1) on a fly ball to left field.
# 4  Nick Martini homers (2) on a fly ball to right center field.    Elly De La Cruz scores.    Spencer Steer scores.
#
#    ExitVelocity  HitDistance  LaunchAngle  \
# 0         101.7   408.819710         33.0
# 1         104.6   406.399234         28.0
# 2         100.3   391.587326         26.0
# 3         101.8   401.081700         28.0
# 4         100.8   389.299792         23.0
#
#                                                                                                                    video
# 0  https://sporty-clips.mlb.com/eVozQWVfWGw0TUFRPT1fQndWWkFWMEFWVkFBQ1ZKV0JBQUFWUUZYQUZnQlVBVUFWd1JSQTFFR0IxRUFVbEFG.mp4
# 1  https://sporty-clips.mlb.com/eVozQWVfWGw0TUFRPT1fVWdWUVZWSlNYd01BWFZFRVZBQUFBd0JYQUFBQ0IxRUFWQVlGQWxVRlZGWUhCZ1VF.mp4
# 2  https://sporty-clips.mlb.com/WmU5ZDhfWGw0TUFRPT1fQkZWWFYxSUhCMVlBQUFSVVZBQUFDRlVGQUFOVFVWQUFWbDFXVkZWUlVnWlFDUXRm.mp4
# 3  https://sporty-clips.mlb.com/eVozQWVfWGw0TUFRPT1fVXdoV0JsWlNCQUVBV1ZWUVh3QUFVQUlFQUZrRVVRQUFWRlFIQUFjQkFnUUVBQVFB.mp4
# 4  https://sporty-clips.mlb.com/a1puZ0JfWGw0TUFRPT1fQlFWVFZ3RlFYbEVBRFZzR1V3QUFCMU5XQUZrTUJWVUFWbE5RVkFGWFVGVlFCZ3RR.mp4

# %% [markdown]
# To render 1 of the public .mp4 videos within the notebook, provide the URL and run the cell below.

# %%
#@title See Single Home Run Video in Notebook

# Pick 1 MLB video URL to see video (default is Shohei Ohtani's 50th HR of 2024)
video_url = 'https://sporty-clips.mlb.com/TVpSTTVfWGw0TUFRPT1fQmdGV1VWUlhWMUFBWEZaVEJ3QUFWUTVYQUZoWFdsY0FWMTBEQndzREFGWUJCbGNF.mp4' #@param {type:"string"}

HTML(f"""<video width="640" height="360" controls>
          <source src="{video_url}" type="video/mp4">
          Your browser does not support the video tag.
        </video>""")
# Out:
# <video width="640" height="360" controls>
#           <source src="https://sporty-clips.mlb.com/TVpSTTVfWGw0TUFRPT1fQmdGV1VWUlhWMUFBWEZaVEJ3QUFWUTVYQUZoWFdsY0FWMTBEQndzREFGWUJCbGNF.mp4" type="video/mp4">
#           Your browser does not support the video tag.
#         </video>

# %% [markdown]
# # Exploring MLB Fan Favorites Data
# ---
# [One of the provided datasets](https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-fan-content-interaction-data/2025-mlb-fan-favs-follows-000000000000.json) has information about fans' favorite teams (1 team per fan) and followed teams (potentially multiple teams per fan) from MLB digital properties.

# %%
#@title Function to Load Newline Delimited JSON into Pandas DF
def load_newline_delimited_json(url):
    """Loads a newline-delimited JSON file from a URL into a pandas DataFrame.

    Args:
        url: The URL of the newline-delimited JSON file.

    Returns:
        A pandas DataFrame containing the data, or None if an error occurs.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes

        data = []
        for line in response.text.strip().split('\n'):
            try:
                data.append(json.loads(line))
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line: {line} due to error: {e}")

        return pd.DataFrame(data)
    except requests.exceptions.RequestException as e:
        print(f"Error downloading data: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
#@title Read in MLB Fan Favorites/Follows Data from Google Cloud Storage
mlb_fan_favorites_json_file = 'https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-fan-content-interaction-data/2025-mlb-fan-favs-follows-000000000000.json'

mlb_fan_favorites_df = load_newline_delimited_json(mlb_fan_favorites_json_file)

# Convert favorite team ID to integer format
mlb_fan_favorites_df['favorite_team_id'] = (
  mlb_fan_favorites_df['favorite_team_id'].astype('Int64'))

display(mlb_fan_favorites_df.head())
# Out:
#            user_id  favorite_team_id                         followed_team_ids
# 0  ECAMUCPLNDAWAT8               108            [119, 114, 143, 142, 110, 108]
# 1  YHL4PR5KKW8H0KS               108  [147, 109, 119, 136, 139, 144, 140, 135]
# 2  TBN0IX5JK19LIB7               108                 [112, 119, 147, 144, 137]
# 3  DXYBMAV0B040YC5               108                                [116, 119]
# 4  UEJ33ZL4CLZTG7P               108                      [121, 137, 147, 119]

# %%
#@title Look at Most Common Favorite MLB Teams
most_common_favorite_teams = (pd.merge(
  mlb_fan_favorites_df['favorite_team_id'].value_counts().reset_index().
    rename(columns = {"count": "num_favorites"}),
  teams[['id', 'name']].
    rename(columns = {"id": "team_id", "name": "team_name"}),
  left_on = 'favorite_team_id',
  right_on = 'team_id',
  how = 'left'
  )[['team_id', 'team_name', 'num_favorites']]
  )

# Create barplot showing most common favorite MLB teams
plt.figure(figsize=(12, 8))
sns.barplot(x='num_favorites', y='team_name', data=most_common_favorite_teams,
    orient='h', color='blue')
plt.title('Most Common Favorite MLB Teams')
plt.xlabel('Number of Favorites')
plt.ylabel('Team Name')

# Add text labels for # of favorites next to each bar
for index, row in most_common_favorite_teams.iterrows():
  plt.text(row['num_favorites'], index, str(row['num_favorites']),
    color='black', ha='left', va='center')

plt.show()

# %%
#@title Look at Most Followed MLB Teams

# Explode the 'followed_team_ids' column to create 1 row for each followed team
mlb_fan_follows_expanded_df = (mlb_fan_favorites_df.
  explode('followed_team_ids').
  reset_index(drop=True)
  )

# Convert followed team IDs to integer format
mlb_fan_follows_expanded_df['followed_team_ids'] = (
  mlb_fan_follows_expanded_df['followed_team_ids'].astype('Int64'))

most_followed_teams = (pd.merge(
  mlb_fan_follows_expanded_df['followed_team_ids'].value_counts().reset_index().
    rename(columns = {"count": "num_followers"}),
  teams[['id', 'name']].
    rename(columns = {"id": "team_id", "name": "team_name"}),
  left_on = 'followed_team_ids',
  right_on = 'team_id',
  how = 'left'
  )[['team_id', 'team_name', 'num_followers']]
  )

# Create barplot showing most followed MLB teams
plt.figure(figsize=(12, 8))
sns.barplot(x='num_followers', y='team_name', data=most_followed_teams,
    orient='h', color='blue')
plt.title('Most Followed MLB Teams')
plt.xlabel('Number of Followers')
plt.ylabel('Team Name')

# Add text labels for # of followers next to each bar
for index, row in most_followed_teams.iterrows():
  plt.text(row['num_followers'], index, str(row['num_followers']),
    color='black', ha='left', va='center')

plt.show()

# %% [markdown]
# # Exploring MLB Fan Content Interaction Data
# ---
# There is [a large dataset](https://console.cloud.google.com/storage/browser/gcp-mlb-hackathon-2025/datasets/mlb-fan-content-interaction-data) with data on the interaction of MLB fans with various content on MLB digital properties. Below, we read in just 1 of the dozens of JSON files with this information in to show what it looks like.

# %%
#@title Read in Example MLB Fan Content Interaction Data File from Google Cloud Storage
mlb_fan_content_interaction_json_file = 'https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-fan-content-interaction-data/mlb-fan-content-interaction-data-000000000000.json'

mlb_fan_content_interaction_df = load_newline_delimited_json(
    mlb_fan_content_interaction_json_file)

display(mlb_fan_content_interaction_df)
# Out:
#        date_time_date              date_time_utc source          user_id  \
# 0          2024-07-30  2024-07-31T03:21:21+00:00    iOS  AZNYWKP68NTBLWN
# 1          2024-07-30  2024-07-30T18:57:53+00:00    iOS  WZO387IQWPX4HTL
# 2          2024-07-30  2024-07-30T23:05:11+00:00    iOS  JIOSQ23LVKD7RHO
# 3          2024-07-30  2024-07-30T19:44:56+00:00    iOS  V9W9G90G6SQZZPF
# 4          2024-07-30  2024-07-31T01:46:07+00:00    iOS  2MM894G4MF56Q2O
# ...               ...                        ...    ...              ...
# 648659     2024-07-30  2024-07-30T20:25:25+00:00    Web  GP4BG6RRDVVLFAU
# 648660     2024-07-30  2024-07-30T17:19:17+00:00    Web  B51H2FOKIG6PKMN
# 648661     2024-07-30  2024-07-30T21:04:24+00:00    Web  B51H2FOKIG6PKMN
# 648662     2024-07-30  2024-07-30T17:12:17+00:00    Web  5ANIWQP1T37E2KV
# 648663     2024-07-30  2024-07-31T02:41:33+00:00    Web  RQPTSEZKFYNNH3S
#
#                                                        slug content_type  \
# 0       rodriguez-charles-combine-to-turn-great-double-play        video
# 1                         chris-okey-hits-a-walk-off-single        video
# 2                         chris-okey-hits-a-walk-off-single        video
# 3                         chris-okey-hits-a-walk-off-single        video
# 4                         chris-okey-hits-a-walk-off-single        video
# ...                                                     ...          ...
# 648659     world-baseball-classic-2026-host-sites-announced      article
# 648660     world-baseball-classic-2026-host-sites-announced      article
# 648661     world-baseball-classic-2026-host-sites-announced      article
# 648662        team-korea-world-baseball-classic-2023-roster      article
# 648663        team-korea-world-baseball-classic-2023-roster      article
#
#                                                                          content_headline  \
# 0                                    Rodriguez, Charles combine to turn great double play
# 1                                                       Chris Okey hits a walk-off single
# 2                                                       Chris Okey hits a walk-off single
# 3                                                       Chris Okey hits a walk-off single
# 4                                                       Chris Okey hits a walk-off single
# ...                                                                                   ...
# 648659  Tokyo, San Juan, Houston and Miami announced as World Baseball Classic 2026 hosts
# 648660  Tokyo, San Juan, Houston and Miami announced as World Baseball Classic 2026 hosts
# 648661  Tokyo, San Juan, Houston and Miami announced as World Baseball Classic 2026 hosts
# 648662                             Pair of Major Leaguers, KBO MVP highlight Korea roster
# 648663                             Pair of Major Leaguers, KBO MVP highlight Korea roster
#
#        team_ids       player_tags
# 0            []  [691497, 800051]
# 1            []          [608360]
# 2            []          [608360]
# 3            []          [608360]
# 4            []          [608360]
# ...         ...               ...
# 648659    [940]                []
# 648660    [940]                []
# 648661    [940]                []
# 648662   [1171]                []
# 648663   [1171]                []
#
# [648664 rows x 9 columns]

# %%
#@title See What Dates, Content Types, and Sources Are Present
date_counts = mlb_fan_content_interaction_df['date_time_date'].value_counts()

display(date_counts)

content_type_counts = (mlb_fan_content_interaction_df['content_type'].
    value_counts())

display(content_type_counts)

content_source_counts = (mlb_fan_content_interaction_df['source'].
    value_counts())

display(content_source_counts)
# Out:
# date_time_date
# 2024-07-30    648664
# Name: count, dtype: int64
# content_type
# video      465867
# article    182797
# Name: count, dtype: int64
# source
# iOS        353133
# Web        224632
# Android     70899
# Name: count, dtype: int64

# %%
#@title Find Content Pieces with Most Interaction in This Data
interaction_by_content = (mlb_fan_content_interaction_df[
    ['slug', 'content_type', 'content_headline']].
    value_counts().
    reset_index().
    rename(columns = {"count": "num_interactions"})
    )

display(interaction_by_content)
# Out:
#                                                                           slug  \
# 0                                           every-2024-mlb-trade-deadline-deal
# 1                                                                 c-2523586283
# 2     jazz-chisholm-jr-homers-17-on-a-fly-ball-to-right-field-juan-soto-scores
# 3                                 aaron-nola-in-play-run-s-to-jazz-chisholm-jr
# 4                                               mlb-rumors-trades-and-signings
# ...                                                                        ...
# 7984                                           jackson-holliday-orioles-callup
# 7985                   jackson-holliday-hits-first-homer-since-triple-a-return
# 7986                                    jackson-chourio-s-two-run-double-x1182
# 7987                      jackson-chourio-s-home-run-through-bat-tracking-data
# 7988                                                   zyhir-hope-s-solo-homer
#
#      content_type                                       content_headline  \
# 0         article                Tracking every 2024 Trade Deadline deal
# 1           video                           Gameday Video Placement clip
# 2           video       Jazz Chisholm Jr.'s second homer of the day (17)
# 3           video                      Jazz Chisholm Jr.'s RBI groundout
# 4         article    'Growing sense' this 8-time All-Star will be traded
# ...           ...                                                    ...
# 7984      article       The Jackson Holliday era has begun for Baltimore
# 7985      article  Holliday hits first homer since returning to Triple-A
# 7986        video                       Jackson Chourio's two-run double
# 7987        video   Jackson Chourio's home run through bat tracking data
# 7988        video                                Zyhir Hope's solo homer
#
#       num_interactions
# 0                35181
# 1                19273
# 2                17492
# 3                11859
# 4                10738
# ...                ...
# 7984                 1
# 7985                 1
# 7986                 1
# 7987                 1
# 7988                 1
#
# [7989 rows x 4 columns]

# %%
#@title Generate MLB.com Link for Article or Video for Specific Content Piece
# Pick single content piece to get link for
content_slug = "every-2024-mlb-trade-deadline-deal" # @param {type:"string"}
content_type = "article" # @param {type:"string"} ['article', 'video']

content_type_cat = ('news' if (content_type == 'article') else 'video')

content_mlb_com_link = f'https://www.mlb.com/{content_type_cat}/{content_slug}'

print(content_mlb_com_link)
# Out:
# https://www.mlb.com/news/every-2024-mlb-trade-deadline-deal

# %% [markdown]
# # Exploring MLB Caption Data
# ---
#
# There is [an interesting text-heavy dataset](https://console.cloud.google.com/storage/browser/gcp-mlb-hackathon-2025/datasets/mlb-caption-data) with captions from the game broadcast of some MLB games, mapped to timestamps within the game (so that you can match play-level data with these captions). Below, we read in all of the JSON files with this information in, combine them into 1 data frame, and do some preliminary analysis.

# %%
#@title Read in All MLB Caption Data from Google Cloud Storage
mlb_captions_base_url = 'https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-caption-data/mlb-captions-data-*.json'
all_dfs = []
i = 0

# Loop over files labeled ""...00" to "...12"
for i in np.arange(0, 13):
    this_url = mlb_captions_base_url.replace("*", str(i).zfill(12))
    this_df = load_newline_delimited_json(this_url)
    all_dfs.append(this_df)
    i += 1

mlb_captions_df = pd.concat(all_dfs, ignore_index=True)

display(mlb_captions_df.head())
# Out:
# Skipping invalid JSON line:  due to error: Expecting value: line 1 column 1 (char 0)
# Error downloading data: 404 Client Error: Not Found for url: https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-caption-data/mlb-captions-data-000000000009.json
# Error downloading data: 404 Client Error: Not Found for url: https://storage.googleapis.com/gcp-mlb-hackathon-2025/datasets/mlb-caption-data/mlb-captions-data-000000000011.json
#      caption_start      caption_end  \
# 0         02:13:28  02:13:42.610000
# 1  04:04:23.465000  04:04:23.630000
# 2  03:16:07.572000  03:16:07.750000
# 3  01:08:21.947000  01:08:22.090000
# 4  00:58:04.797000  00:58:04.960000
#
#                                                                                                                                                                                               caption_text  \
# 0  And part of my thinking here, Steven Vogt leaving him in is not so much the fifth inning that may be sacrificing this matchup in the fifth, but perhaps it will be a righty when he comes around aga...
# 1                                                                                                                                                                                                      So.
# 2                                                                                                                                                                                                     100.
# 3                                                                                                                                                                                                     Now.
# 4                                                                                                                                                                                                     One.
#
#                          write_date game_pk feed_type
# 0  2024-09-20T07:32:20.420407+00:00  746579         A
# 1  2024-09-20T07:32:20.420407+00:00  746579         A
# 2  2024-09-20T07:32:20.420407+00:00  746579         A
# 3  2024-09-20T07:32:20.420407+00:00  746579         A
# 4  2024-09-20T07:32:20.420407+00:00  746579         A

# %%
#@title See What Dates and Feed Types Are Present
# Convert 'write_date' to date only field
mlb_captions_df['write_date_only'] = (pd.to_datetime(
    mlb_captions_df['write_date']).dt.date)

date_counts = mlb_captions_df['write_date_only'].value_counts()

display(date_counts)

feed_type_counts = mlb_captions_df['feed_type'].value_counts()

display(feed_type_counts)
# Out:
# write_date_only
# 2024-09-19    72721
# 2024-09-22    67778
# 2024-09-21    58176
# 2024-09-26    53861
# 2024-09-18    50628
# 2024-09-29    44870
# 2024-09-25    41066
# 2024-09-27    34961
# 2024-09-17    27606
# 2024-09-20    22291
# 2024-09-23    21038
# 2024-09-24    15361
# 2024-09-28    12669
# 2024-09-30     9863
# 2024-10-01     7246
# Name: count, dtype: int64
# feed_type
# H    271118
# A    269017
# Name: count, dtype: int64

# %%
#@title Get MLB Film Room Video Clip for Last Play from Specific Game
# Pick game to get last play from (default is game_pk 747066, for Braves-Royals
# game with Travis d'Arnaud walk-off HR on 9/28/2024)
game_pk = '747066' #@param{type:"string"}

single_game_feed_url = f'https://statsapi.mlb.com/api/v1.1/game/{game_pk}/feed/live'

single_game_info_json = json.loads(requests.get(single_game_feed_url).content)

single_game_play = single_game_info_json['liveData']['plays']['currentPlay']

single_game_play_id = single_game_play['playEvents'][-1]['playId']

single_play_video_url = f'https://www.mlb.com/video/search?q=playid=\"{single_game_play_id}\"'

display(single_play_video_url)
# Out:
# 'https://www.mlb.com/video/search?q=playid="ba04fcba-8fea-4f49-8768-6dc9230bbbe5"'

# %%
#@title Get Captions Data Corresponding to Specific Play

# This is specific to the walk-off HR in game_pk 747066, with caption time codes
# found manually
single_play_captions = (mlb_captions_df[
    (mlb_captions_df['game_pk'] == game_pk)
    &
    (mlb_captions_df['feed_type'] == 'H')
    &
    (mlb_captions_df['caption_start'] >= '03:08:25.00000')
    &
    (mlb_captions_df['caption_end'] <= '03:10:21.0000')
    ].
    sort_values(['caption_start']).
    reset_index(drop = True)
    )

display(single_play_captions[['caption_start', 'caption_end', 'caption_text']])
# Out:
#       caption_start      caption_end  \
# 0   03:08:25.594000  03:08:38.740000
# 1   03:08:38.740000  03:08:45.310000
# 2   03:08:45.314000  03:09:10.130000
# 3   03:09:10.138000  03:09:15.240000
# 4   03:09:15.243000  03:09:19.580000
# 5   03:09:19.581000  03:09:25.350000
# 6   03:09:25.354000  03:09:31.360000
# 7   03:09:31.360000  03:10:03.220000
# 8   03:10:03.225000  03:10:08.860000
# 9   03:10:08.864000  03:10:10.380000
# 10  03:10:10.382000  03:10:12.060000
# 11  03:10:12.067000  03:10:20.940000
#
#                                                                                                                                             caption_text
# 0   >> Now Travis Otano first time facing the Royals since 2016, Travis has not seen much of the Royals, but he's got a spohere in the ninthith one out.
# 1                                                                                                    body on where he can ctainly make an impact impact.
# 2                                               Downstairs, two balls, no strikes to the Braves catcher catcherDa catcherDat catcherDa catcherDar field.
# 3                                                                                                                          It's deep and it's gone gone.
# 4                                                                                       >> Travis Darnel with the biggest home run of the Braves season.
# 5                                                                                                                           And they walk it off 2 to 1.
# 6                                                                                                                                               Now Now.
# 7                                                                                                                                  Larrondo Dalvy Dalvy.
# 8                                                                                            Something is eling different about this team right now now.
# 9                                                                                                             >> And what we are seeing when it matters.
# 10                                                                                                                                             The most.
# 11                                          And what a moment for Travis Otano second whichend has hit a wa off homer, he's ahead in the count two zero.

# %% [markdown]
# # Other Resources
# ---
#
# Below are a few other resources related to the hackathon or MLB in general that may be useful.
#
# *   [Google Cloud x MLB Hackathon Resources GitHub Repo](https://github.com/MajorLeagueBaseball/google-cloud-mlb-hackathon)
# *   [MLB Glossary](https://www.mlb.com/glossary)
# *   ["MLB-StatsAPI" Python library to wrap MLB Stats API](https://pypi.org/project/MLB-StatsAPI/)
# *   ["baseballR" R library to wrap MLB Stats API](https://cran.r-project.org/web/packages/baseballr/index.html)
